# %% [markdown]
# # Equipment Failure Prediction - Quick Start
#
# This notebook demonstrates the basic usage of the Equipment Failure Prediction System.
#
# **⚠️ DISCLAIMER: This is an experimental research/educational project. DO NOT use for automated maintenance decisions without human review.**
